# %%
# from one_stage import ConvResidualBlock
import torch
import torch.nn as nn
from backbone import Darknet53
from backbone import ConvResidualBlock

# %%
# def __init__(self, in_channels1, out_channels1, in_channels2, out_channels2, bias=False):
block = ConvResidualBlock(64)
net = Darknet53()

# %%
x = torch.randn(1, 3, 1920, 1920)
out = net(x)
# Out:
# before residual block1:  torch.Size([1, 64, 960, 960])
# torch.Size([1, 64, 960, 960])

# %%
print(out.shape)
# Out:
# torch.Size([1, 1000])
